# %% [markdown]
# **Тут будут шпаргалки, краткие заметки по разным темам**

# %% [markdown]
# ***PYTHON-11. Базовые приёмы работы с данными в Pandas***

# %% [markdown]
# Feature Engineering - методология преобразования данных для повышения качества моделей и увеличения скорости их обучения

# %% [markdown]
# В Pandas форматом времени является datetime, который записывается как YYYY-MM-DD HH: MM: SS, то есть составляющие времени указываются в следующем порядке: год, месяц, день, час, минута, секунда.
# Для того чтобы преобразовывать столбцы с датами, записанными в распространённых форматах, в формат datetime, можно воспользоваться функцией **pandas.to_datetime()**.
# Бывает, что в функции нужно указать параметр **dayfirst=True**, который будет обозначать, что в первоначальном признаке первым идет день.
#
# ***data_frame['Date'] = pandas.to_datetime(data_frame['Date'], dayfirst=True)***

# %% [markdown]
# Под **числовыми** признаками обычно подразумевают признаки, которые отражают количественную меру и могут принимать значения из неограниченного диапазона.
# Числовые признаки могут быть ***дискретными*** (например, количество комнат, пациентов, дней, отток сотрудников) или ***непрерывными*** (например, масса, цена, площадь).
# Дискретные признаки чаще всего представлены целыми числами, а непрерывные — целыми числами и числами с плавающей точкой.
#
# Под **категориальными** признаками обычно подразумевают столбцы в таблице, которые обозначают принадлежность объекта к какому-то классу/категории.
# Категориальные признаки могут быть ***номинальными*** (например, пол, национальность, район) или ***порядковыми*** (например, уровень образования, уровень комфорта, стадия заболевания).
# Такие признаки имеют ограниченный набор значений. Они чаще всего представлены в виде текстового описания и кодируются в Pandas типом данных object.

# %% [markdown]
# ***PYTHON-12. Продвинутые методы работы с данными в Pandas***

# %% [markdown]
# CSV-файл не хранит в себе информацию о типах данных столбцов, поэтому при чтении Pandas автоматически определяет тип данных столбца.
